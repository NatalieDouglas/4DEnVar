# %%
## Import global variables, tools, libraries and functions
import global_vars
import importlib
importlib.reload(global_vars)
execfile('global_vars.py')

# %%
## Run 4DEnVar experiment exp_size times for varying ensemble size
exp_size=5
ens_sizes=np.arange(5,100,10)
RMSEexp=np.zeros((2,exp_size,len(ens_sizes)))

for i in range(0,exp_size):
    
    rmse_anal_1 = []
    rmse_anal_2 = []
    j=0
    
    while j < len(ens_sizes):
        
        x_ens=[]
        hxbar=[]
        hX=[]
        
        GE = genensemble_class.genensemble_class(ens_sizes[j], g_xb, g_B_mat, g_val_bnds)
        x_ens=GE.ens
        
        GF = genDAfeatures_class.genDAfeatures_class(g_initstate, g_tf, g_deltat, g_forcing, x_ens)
        [hxbar,hX]=[GF.hxbar,GF.hX]
        [hxbar_mat,hX_mat]=[GF.hxbar_mat,GF.hX_mat]
        
        rmse_hxbar_1 = RMSE(hxbar_mat[0],g_xtrue_noise[0])
        rmse_hxbar_2 = RMSE(hxbar_mat[1],g_xtrue_noise[1])
        
        DA=fourDEnVar_engine.fourDEnVar_engine(x_ens, hX, g_y, g_R, hxbar)
        xa=DA.xa
        Xa=DA.Xa
        anal=DA.xa_analytical
        print(xa)
        print(anal)
        
        MR = modelruns_class.modelruns_class(g_initstate, g_tf, g_deltat, g_forcing, xa)
        hanal_mat = MR.xf
        rmse1=RMSE(hanal_mat[0],g_xtrue_noise[0])
        rmse2=RMSE(hanal_mat[1],g_xtrue_noise[1])
        
        ## DA fails if parameters fall outside permitted range or RMSE is high
        test = 1
        string = 'failed_ensemble'
        for n in range(0,4):
            if xa[n] < g_val_bnds[n][0] or xa[n] > g_val_bnds[n][1]:
                test = 0
                string += '_'+g_xlabels[n]+'_exp'+str(i)+'_ens'+str(ens_sizes[j])
                print(g_xlabels[n]+'parameter out of bounds in exper. '+str(i)+'and ens. size '+str(ens_sizes[j]))
        if rmse1 >100 or rmse2>100:
            test=0
            string += '_highRMSE'
        
        ## output the failed ensemble if DA is considered to fail as above, append RMSE for plotting otherwise
        if test == 0:
            np.save(string+'.npy',x_ens)
        else:
            j+=1
            rmse_anal_1.append(rmse1)
            rmse_anal_2.append(rmse2)
    
    RMSEexp[0,i,:]=rmse_anal_1
    RMSEexp[1,i,:]=rmse_anal_2
# Out:
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.91340423 0.72225599 0.12784963 0.08390226]
# [0.9134043  0.72225606 0.12784962 0.08390226]
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.37872097 1.68054439 0.22107059 0.10425658]
# [0.37828526 1.6809966  0.22106957 0.10426097]
# $p_1$parameter out of bounds in exper.0and ens. size15
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.72917342 1.66636092 0.17052372 0.09521442]
# [0.7289735  1.66637998 0.17055901 0.09521696]
# shape of X_dash_b: (4, 25)
# shape of Y_dash_b: (2002, 25)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.99592871 2.02746446 0.2098432  0.08825247]
# [0.99595414 2.02746304 0.20983312 0.08825269]
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.08244792 1.89720571 0.2354512  0.09292609]
# [0.0820562  1.89808104 0.23547772 0.09292291]
# $p_1$parameter out of bounds in exper.0and ens. size35
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.88139119 1.4207028  0.19275295 0.08746892]
# [0.88165373 1.41977929 0.19279643 0.08746652]
# shape of X_dash_b: (4, 45)
# shape of Y_dash_b: (2002, 45)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.83580864 1.34276081 0.19933862 0.08992174]
# [0.83563013 1.34321055 0.19933227 0.08992021]
# shape of X_dash_b: (4, 55)
# shape of Y_dash_b: (2002, 55)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.53266821 2.09049821 0.20534904 0.09019637]
# [0.53287374 2.09041159 0.20531024 0.09019327]
# shape of X_dash_b: (4, 65)
# shape of Y_dash_b: (2002, 65)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.92616168 1.59224898 0.22498651 0.09298036]
# [0.92523231 1.5932813  0.2249991  0.09297992]
# shape of X_dash_b: (4, 75)
# shape of Y_dash_b: (2002, 75)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.70372621 1.77281547 0.20382778 0.08899948]
# [0.70404265 1.77303228 0.20383887 0.08899503]
# shape of X_dash_b: (4, 85)
# shape of Y_dash_b: (2002, 85)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.78326485 1.29303267 0.19754345 0.09048954]
# [0.78308786 1.29298911 0.19753361 0.09049407]
# shape of X_dash_b: (4, 95)
# shape of Y_dash_b: (2002, 95)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.66059232 1.80338634 0.20886453 0.0906429 ]
# [0.66067001 1.80287945 0.20887304 0.09064982]
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [1.21616037 1.75199421 0.14188006 0.0810896 ]
# [1.21616021 1.7519942  0.14188001 0.08108962]
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.68285844 1.88108082 0.21053347 0.08771432]
# [0.68171371 1.88270135 0.21050625 0.08772002]
# shape of X_dash_b: (4, 25)
# shape of Y_dash_b: (2002, 25)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [1.14207577 0.92195845 0.20091472 0.08214639]
# [1.14202606 0.92186916 0.20091869 0.08214687]
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.46478673 2.78576038 0.22046062 0.08929543]
# [0.46449528 2.78624341 0.22047479 0.08929375]
# $p_1$parameter out of bounds in exper.1and ens. size35
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.62892781 2.11873895 0.19782715 0.08542606]
# [0.62932613 2.11852794 0.19777588 0.08542662]
# shape of X_dash_b: (4, 45)
# shape of Y_dash_b: (2002, 45)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.61681466 1.56029943 0.21346612 0.0866368 ]
# [0.61707649 1.55996714 0.21348978 0.08663736]
# shape of X_dash_b: (4, 55)
# shape of Y_dash_b: (2002, 55)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.73969811 1.86149106 0.21567624 0.08602705]
# [0.73974162 1.86093883 0.21567926 0.08603029]
# shape of X_dash_b: (4, 65)
# shape of Y_dash_b: (2002, 65)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.71584974 1.68710938 0.20312308 0.08927893]
# [0.71613943 1.68667802 0.20310842 0.08927913]
# shape of X_dash_b: (4, 75)
# shape of Y_dash_b: (2002, 75)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.78455319 1.56454914 0.20225525 0.0913927 ]
# [0.78488541 1.56371422 0.20222238 0.0913966 ]
# shape of X_dash_b: (4, 85)
# shape of Y_dash_b: (2002, 85)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.86641449 1.56362538 0.20060835 0.08630981]
# [0.86651369 1.56317117 0.20059872 0.08631127]
# shape of X_dash_b: (4, 95)
# shape of Y_dash_b: (2002, 95)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.68365286 1.87244413 0.19783904 0.08880985]
# [0.68370396 1.87215241 0.19784419 0.08881395]
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.90033094 1.62513515 0.20829824 0.09551978]
# [0.900331   1.62513505 0.20829824 0.09551977]
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [1.04891555 1.62447664 0.19557371 0.08221592]
# [1.04934268 1.62282077 0.19555286 0.08221598]
# shape of X_dash_b: (4, 25)
# shape of Y_dash_b: (2002, 25)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.75818358 1.14336871 0.20552277 0.08369815]
# [0.7582829  1.143359   0.20555292 0.0836994 ]
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.66744717 1.6178187  0.20974456 0.09225294]
# [0.66769791 1.61771941 0.20974051 0.09225239]
# shape of X_dash_b: (4, 45)
# shape of Y_dash_b: (2002, 45)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.62731148 1.9310115  0.22532226 0.08574206]
# [0.62771069 1.93033082 0.22535535 0.08574259]
# shape of X_dash_b: (4, 55)
# shape of Y_dash_b: (2002, 55)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.50893885 1.8196838  0.20738913 0.09208666]
# [0.50848018 1.82002398 0.20740088 0.09208848]
# shape of X_dash_b: (4, 65)
# shape of Y_dash_b: (2002, 65)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.69810213 1.6456232  0.19313241 0.0873036 ]
# [0.69823463 1.64538756 0.19313671 0.0873039 ]
# shape of X_dash_b: (4, 75)
# shape of Y_dash_b: (2002, 75)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.85214514 1.37724615 0.20248046 0.08913665]
# [0.851628   1.37814019 0.20251762 0.0891365 ]
# shape of X_dash_b: (4, 85)
# shape of Y_dash_b: (2002, 85)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.75669274 1.62175892 0.2048977  0.09253292]
# [0.75702095 1.62128871 0.20489325 0.09253126]
# shape of X_dash_b: (4, 95)
# shape of Y_dash_b: (2002, 95)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.76145472 1.64293133 0.20661598 0.09099036]
# [0.76155139 1.64276755 0.20663788 0.09098828]
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [-1.19652616  5.80673909  0.1629639   0.07902947]
# [-1.19652616  5.80673909  0.1629639   0.07902947]
# $p_1$parameter out of bounds in exper.3and ens. size5
# $p_2$parameter out of bounds in exper.3and ens. size5
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.60973642 2.39759073 0.2033692  0.08190388]
# [0.60973953 2.39758505 0.20336929 0.08190384]
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [1.13541591 1.06561366 0.1747055  0.08379313]
# [1.1352987  1.06589488 0.17468076 0.08379884]
# shape of X_dash_b: (4, 25)
# shape of Y_dash_b: (2002, 25)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.93171265 1.61497931 0.17173325 0.08414   ]
# [0.9321727  1.61372418 0.17178813 0.08414326]
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.95241588 1.18545252 0.20519751 0.08946369]
# [0.95250162 1.18529741 0.20522331 0.08946411]
# shape of X_dash_b: (4, 45)
# shape of Y_dash_b: (2002, 45)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.75757953 1.49161304 0.20022116 0.08980659]
# [0.75803163 1.49074659 0.20021049 0.08980703]
# shape of X_dash_b: (4, 55)
# shape of Y_dash_b: (2002, 55)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.75142398 1.89673129 0.20461931 0.08981607]
# [0.75164035 1.89632883 0.20464424 0.08981465]
# shape of X_dash_b: (4, 65)
# shape of Y_dash_b: (2002, 65)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.79993237 1.61651575 0.20286538 0.08590301]
# [0.79991372 1.61641528 0.20286046 0.085903  ]
# shape of X_dash_b: (4, 75)
# shape of Y_dash_b: (2002, 75)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.62766395 1.99913214 0.20658991 0.09063191]
# [0.62806983 1.99738528 0.20657961 0.09064245]
# shape of X_dash_b: (4, 85)
# shape of Y_dash_b: (2002, 85)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.69548651 1.86097953 0.21160016 0.09245274]
# [0.6952171  1.86056717 0.21153251 0.09245481]
# shape of X_dash_b: (4, 95)
# shape of Y_dash_b: (2002, 95)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.62219944 1.8737745  0.21871184 0.08782556]
# [0.62244456 1.87334603 0.2187242  0.08782569]
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [ 1.29324355 -0.73237557  0.37403985  0.06546371]
# [ 1.29324294 -0.73237132  0.37403976  0.0654637 ]
# $p_2$parameter out of bounds in exper.4and ens. size5
# shape of X_dash_b: (4, 5)
# shape of Y_dash_b: (2002, 5)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.90808621 1.51209775 0.19895759 0.07833045]
# [0.9080845  1.51209796 0.19895789 0.07833049]
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.39142489 1.55841857 0.29292538 0.08025901]
# [0.38980558 1.56033106 0.29292763 0.08026246]
# $p_1$parameter out of bounds in exper.4and ens. size15
# shape of X_dash_b: (4, 15)
# shape of Y_dash_b: (2002, 15)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [1.00343666 1.19709213 0.17466213 0.08715152]
# [1.00324011 1.19714424 0.1746764  0.08715319]
# shape of X_dash_b: (4, 25)
# shape of Y_dash_b: (2002, 25)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.51181635 2.17180747 0.20505617 0.08482635]
# [0.51196244 2.17089898 0.20508821 0.0848306 ]
# shape of X_dash_b: (4, 35)
# shape of Y_dash_b: (2002, 35)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.87017232 2.30688064 0.20091402 0.0810473 ]
# [0.87036525 2.30629149 0.20092844 0.08105294]
# shape of X_dash_b: (4, 45)
# shape of Y_dash_b: (2002, 45)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.51667967 2.01004802 0.1983174  0.09427898]
# [0.51713234 2.00921522 0.19831203 0.09428629]
# shape of X_dash_b: (4, 55)
# shape of Y_dash_b: (2002, 55)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.61374527 1.88881333 0.21887662 0.09192765]
# [0.61349785 1.88959058 0.21889084 0.09192132]
# shape of X_dash_b: (4, 65)
# shape of Y_dash_b: (2002, 65)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.9320589  1.1323535  0.20884674 0.09079992]
# [0.93218695 1.13210159 0.20884664 0.09080451]
# shape of X_dash_b: (4, 75)
# shape of Y_dash_b: (2002, 75)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.97192139 1.16575735 0.19708524 0.09100817]
# [0.9721274  1.16518039 0.19707819 0.09101067]
# shape of X_dash_b: (4, 85)
# shape of Y_dash_b: (2002, 85)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.68797716 1.84775104 0.21015456 0.08722618]
# [0.68805065 1.84782325 0.21019029 0.08722776]
# shape of X_dash_b: (4, 95)
# shape of Y_dash_b: (2002, 95)
# Xbdash*inv(I+Ybdash^T*Rinv*Ybdash)*Xbdash^T is symmetric and all eigenvalues are positive
# [0.852756   1.35373026 0.1977277  0.08808046]
# [0.85221654 1.35474846 0.19771826 0.08807911]

# %%
## Plot mean, 10th and 90th percentiles for RMSE against ensemble size

RMSE1_mean=np.mean(RMSEexp[0,:,:],0) 
RMSE2_mean=np.mean(RMSEexp[1,:,:],0) 
RMSE1_10=np.percentile(RMSEexp[0,:,:],10,axis=0)
RMSE2_10=np.percentile(RMSEexp[1,:,:],10,axis=0)
RMSE1_90=np.percentile(RMSEexp[0,:,:],90,axis=0)
RMSE2_90=np.percentile(RMSEexp[1,:,:],90,axis=0)
plt.figure(figsize=(10,4))
plt.plot(ens_sizes,RMSE1_mean,label=r'mean rmse in $x_1$',color='r')
plt.plot(ens_sizes,RMSE2_mean,label=r'mean rmse in $x_2$',color='b')
plt.plot(ens_sizes,RMSE1_10,label=r'10th percentile rmse in $x_1$',color='r', linestyle='dashed')
plt.plot(ens_sizes,RMSE2_10,label=r'10th percentile rmse in $x_2$',color='b', linestyle='dashed')
plt.plot(ens_sizes,RMSE1_90,label=r'90th percentile rmse in $x_1$',color='r', linestyle='dashed')
plt.plot(ens_sizes,RMSE2_90,label=r'90th percentile rmse in $x_2$',color='b', linestyle='dashed')
plt.fill_between(ens_sizes,RMSE1_90,RMSE1_10, color='r',alpha=0.3)
plt.fill_between(ens_sizes,RMSE2_90,RMSE2_10, color='b', alpha=0.3)
plt.legend()
plt.xlabel('Ensemble Size')
plt.ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')
